# %% [markdown]
# ## Data Preprocessing

# %%
# %%capture
#Load exploratory_data_analysis file
# %run exploratory_data_analysis.ipynb

# %%
dataset.head(2)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female             0     Yes         No       1           No
# 1  5575-GNVDE    Male             0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0  Electronic check          29.85         29.85     No
# 1      Mailed check          56.95       1889.50     No
#
# [2 rows x 21 columns]

# %%
#Convert TotalCharges column into float
dataset["SeniorCitizen"] = pd.to_numeric(dataset["SeniorCitizen"], errors="coerce")

# %%
#Map all columns with yes and t=no to numerical values
variables = ["Partner", "Dependents", "PhoneService", "OnlineSecurity", "PaperlessBilling", "Churn", 
             "MultipleLines", "OnlineSecurity", "OnlineBackup", "DeviceProtection", "TechSupport",
            "StreamingTV", "StreamingMovies"]
#Mapping dictionary
mapping = {"Yes": 1, "No": 0}

#Convert variables column to numeric
for variable in variables:
    dataset[variable] = dataset[variable].map(mapping).fillna(2).astype(int)

# %%
dataset.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female              0        1           0       1
# 1  5575-GNVDE    Male              0        0           0      34
# 2  3668-QPYBK    Male              0        0           0       2
# 3  7795-CFOCW    Male              0        0           0      45
# 4  9237-HQITU  Female              0        0           0       2
#
#    PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# 0             0              2             DSL               2  ...
# 1             1              0             DSL               2  ...
# 2             1              0             DSL               2  ...
# 3             0              2             DSL               2  ...
# 4             1              0     Fiber optic               2  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                 0            0            0                0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
#Variables to encode
var = ["gender", "InternetService", "Contract", "PaymentMethod"]
encoder = LabelEncoder()
#Convert variables column to numeric
for variable in var:
    dataset[variable] = encoder.fit_transform(dataset[variable])

# %%
#Drop customerID column
dataset = dataset.drop(columns=["customerID"])

# %%
dataset.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              2                0               2             1
# 1              0                0               2             0
# 2              0                0               2             1
# 3              2                0               2             0
# 4              0                1               2             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int32
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int32
#  4   Dependents        7043 non-null   int32
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int32
#  7   MultipleLines     7043 non-null   int32
#  8   InternetService   7043 non-null   int32
#  9   OnlineSecurity    7043 non-null   int32
#  10  OnlineBackup      7043 non-null   int32
#  11  DeviceProtection  7043 non-null   int32
#  12  TechSupport       7043 non-null   int32
#  13  StreamingTV       7043 non-null   int32
#  14  StreamingMovies   7043 non-null   int32
#  15  Contract          7043 non-null   int32
# ...
